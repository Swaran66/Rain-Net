# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
import missingno as miss
import datetime as date
import keras_tuner
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cb3a3a71ee3b> in <cell line: 7>()
#       5 import missingno as miss
#       6 import datetime as date
# ----> 7 import keras_tuner
#
# ModuleNotFoundError: No module named 'keras_tuner'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [raw]
# "D:\\wallpapers and photos\\paper\\raj_SPEI_01_month.csv"
# "D:\\wallpapers and photos\\paper\\syl_SPEI_01_month.csv"
# "D:\\wallpapers and photos\\paper\\ctg_SPEI_01_month.csv"

# %% [markdown]
# ### My thoughts behind this process:
# We look for the ideal mix of variables for real data and our training method. As a result, we will utilize our data for our training process—all variables from 2001 to 2019—and use model diagnosis (SHAP) to identify which variable contributed the most. In the end, we can utilize the variables that have the largest impacts on actual data prediction if needed, and we can use those values to forecast real data again, and so on, to cut down on needless complexity.

# %%
rain=pd.read_csv("D:\\wallpapers and photos\\paper\\ctg_SPEI_01_month.csv")

# %%
rain
# Out:
#      month  year      SPEI      CHIRPS      IMERGE     LST_DAY   LST_Night  \
# 0        1  1990 -1.440798    4.715943         NaN         NaN         NaN
# 1        2  1990  1.587341   32.093627         NaN         NaN         NaN
# 2        3  1990  1.694348   81.816802         NaN         NaN         NaN
# 3        4  1990  0.842682  129.246161         NaN         NaN         NaN
# 4        5  1990  0.274244  227.500759         NaN         NaN         NaN
# ..     ...   ...       ...         ...         ...         ...         ...
# 355      8  2019 -1.266436  719.174234  415.233358  308.000217  301.812465
# 356      9  2019  0.720027  312.809505  382.310666  307.674666  302.258737
# 357     10  2019 -0.017451  153.181688  168.655851  305.435565  300.115824
# 358     11  2019  0.443243  109.113888   90.805858  302.333352  294.946265
# 359     12  2019  0.706380   10.753311    8.350516  298.043410  289.657623
#
#      Real Data
# 0            0
# 1           39
# 2           53
# ...

# %%
miss.matrix(rain)
# Out:
# <Axes: >

# %%
rain["date"]=pd.to_datetime(rain[["year","month"]].assign(day=1))
rain
# Out:
#      month  year      SPEI      CHIRPS      IMERGE     LST_DAY   LST_Night  \
# 0        1  1990 -1.440798    4.715943         NaN         NaN         NaN
# 1        2  1990  1.587341   32.093627         NaN         NaN         NaN
# 2        3  1990  1.694348   81.816802         NaN         NaN         NaN
# 3        4  1990  0.842682  129.246161         NaN         NaN         NaN
# 4        5  1990  0.274244  227.500759         NaN         NaN         NaN
# ..     ...   ...       ...         ...         ...         ...         ...
# 355      8  2019 -1.266436  719.174234  415.233358  308.000217  301.812465
# 356      9  2019  0.720027  312.809505  382.310666  307.674666  302.258737
# 357     10  2019 -0.017451  153.181688  168.655851  305.435565  300.115824
# 358     11  2019  0.443243  109.113888   90.805858  302.333352  294.946265
# 359     12  2019  0.706380   10.753311    8.350516  298.043410  289.657623
#
#      Real Data       date
# 0            0 1990-01-01
# ...

# %%
rain=rain[["date","SPEI","CHIRPS","IMERGE","LST_DAY","LST_Night","Real Data"]]

# %%
rain
# Out:
#           date      SPEI      CHIRPS      IMERGE     LST_DAY   LST_Night  \
# 0   1990-01-01 -1.440798    4.715943         NaN         NaN         NaN
# 1   1990-02-01  1.587341   32.093627         NaN         NaN         NaN
# 2   1990-03-01  1.694348   81.816802         NaN         NaN         NaN
# 3   1990-04-01  0.842682  129.246161         NaN         NaN         NaN
# 4   1990-05-01  0.274244  227.500759         NaN         NaN         NaN
# ..         ...       ...         ...         ...         ...         ...
# 355 2019-08-01 -1.266436  719.174234  415.233358  308.000217  301.812465
# 356 2019-09-01  0.720027  312.809505  382.310666  307.674666  302.258737
# 357 2019-10-01 -0.017451  153.181688  168.655851  305.435565  300.115824
# 358 2019-11-01  0.443243  109.113888   90.805858  302.333352  294.946265
# 359 2019-12-01  0.706380   10.753311    8.350516  298.043410  289.657623
#
#      Real Data
# 0            0
# 1           39
# 2           53
# 3          250
# ...

# %%
rain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       360 non-null    datetime64[ns]
#  1   SPEI       360 non-null    float64
#  2   CHIRPS     360 non-null    float64
#  3   IMERGE     228 non-null    float64
#  4   LST_DAY    228 non-null    float64
#  5   LST_Night  228 non-null    float64
#  6   Real Data  360 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 19.8 KB

# %%
rain[134:]
# Out:
#           date      SPEI      CHIRPS      IMERGE     LST_DAY   LST_Night  \
# 134 2001-03-01 -0.367564   23.109298   13.079091  306.100558  293.616292
# 135 2001-04-01 -0.787717   51.142762   51.683306  310.277379  297.860993
# 136 2001-05-01 -0.245257  307.985096  402.869898  306.759751  298.907355
# 137 2001-06-01 -0.652502  663.798851  871.690367  306.074816  292.874378
# 138 2001-07-01 -0.356688  527.327652  457.183686  614.084272  578.960248
# ..         ...       ...         ...         ...         ...         ...
# 355 2019-08-01 -1.266436  719.174234  415.233358  308.000217  301.812465
# 356 2019-09-01  0.720027  312.809505  382.310666  307.674666  302.258737
# 357 2019-10-01 -0.017451  153.181688  168.655851  305.435565  300.115824
# 358 2019-11-01  0.443243  109.113888   90.805858  302.333352  294.946265
# 359 2019-12-01  0.706380   10.753311    8.350516  298.043410  289.657623
#
#      Real Data
# 134          1
# 135         41
# 136        423
# 137        389
# ...

# %%
from feature_engine.wrappers import SklearnTransformerWrapper
from sklearn.preprocessing import StandardScaler
scale=SklearnTransformerWrapper(transformer=StandardScaler(),variables=["SPEI","CHIRPS","IMERGE","LST_DAY","LST_Night","Real Data"])
rain=scale.fit_transform(rain)
rain
# Out:
#           date      SPEI    CHIRPS    IMERGE   LST_DAY  LST_Night  Real Data
# 0   1990-01-01 -1.438668 -0.943595       NaN       NaN        NaN  -0.826823
# 1   1990-02-01  1.796774 -0.833907       NaN       NaN        NaN  -0.695896
# 2   1990-03-01  1.911106 -0.634694       NaN       NaN        NaN  -0.648897
# 3   1990-04-01  1.001137 -0.444670       NaN       NaN        NaN   0.012449
# 4   1990-05-01  0.393784 -0.051018       NaN       NaN        NaN  -0.138620
# ..         ...       ...       ...       ...       ...        ...        ...
# 355 2019-08-01 -1.252369  1.918847  0.745888  0.123120   0.233112   0.737580
# 356 2019-09-01  0.870085  0.290767  0.609859  0.107447   0.256306   0.398514
# 357 2019-10-01  0.082120 -0.348774 -0.272910 -0.000353   0.144935  -0.413901
# 358 2019-11-01  0.574352 -0.525329 -0.594567 -0.149706  -0.123734  -0.548185
# 359 2019-12-01  0.855503 -0.919406 -0.935252 -0.356242  -0.398593  -0.793252
#
# [360 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set_theme(rc={'figure.figsize':(11.7,8.27)})
# %matplotlib inline

# %%
sns.lineplot(x="date",y="Real Data",data=rain)
# Out:
# <Axes: xlabel='date', ylabel='Real Data'>

# %%
sns.lineplot(x="date",y="SPEI",data=rain)
# Out:
# <Axes: xlabel='date', ylabel='SPEI'>

# %%
sns.lineplot(x="date",y="LST_Night",data=rain)
# Out:
# <Axes: xlabel='date', ylabel='LST_Night'>

# %%
sns.lineplot(data=rain)
# Out:
# <Axes: >

# %% [markdown]
# ### Cleaning the data with isolation forest

# %%
from sklearn.ensemble import IsolationForest
iso_forest = IsolationForest(contamination=0.1)
outliers = iso_forest.fit_predict(rain[134:].drop(["date"],axis=1))
rain_clean = rain[134:][outliers == 1]
rain_clean
# Out:
#           date      SPEI    CHIRPS    IMERGE   LST_DAY  LST_Night  Real Data
# 134 2001-03-01 -0.291962 -0.869903 -0.915715  0.031663  -0.192855  -0.823466
# 135 2001-04-01 -0.740878 -0.757588 -0.756212  0.232753   0.027748  -0.689182
# 136 2001-05-01 -0.161282  0.271438  0.694805  0.063399   0.082129   0.593225
# 139 2001-08-01 -0.003382  1.692436  0.499602  0.060172   0.067369  -0.027836
# 140 2001-09-01  0.628523  0.083971  0.225102  0.028206   0.127893  -0.074835
# ..         ...       ...       ...       ...       ...        ...        ...
# 352 2019-05-01 -1.296630 -0.286440 -0.229146  0.114651   0.173555  -0.135263
# 356 2019-09-01  0.870085  0.290767  0.609859  0.107447   0.256306   0.398514
# 357 2019-10-01  0.082120 -0.348774 -0.272910 -0.000353   0.144935  -0.413901
# 358 2019-11-01  0.574352 -0.525329 -0.594567 -0.149706  -0.123734  -0.548185
# 359 2019-12-01  0.855503 -0.919406 -0.935252 -0.356242  -0.398593  -0.793252
#
# [203 rows x 7 columns]

# %% [markdown]
# ### Plot after treating outlier

# %%
rain_plot_before=rain[["date","SPEI","CHIRPS"]]
rain_plot_after=rain_clean[["date","SPEI","CHIRPS"]]

# %%
fig, axes = plt.subplots(1, 2)

#create chart in each subplot
sns.lineplot(data=rain_plot_after, ax=axes[1]).set(title="After")
sns.lineplot(data=rain_plot_before, ax=axes[0]).set(title="Before")
# Out:
# [Text(0.5, 1.0, 'Before')]

# %%
train_set, test_set= np.split(rain_clean, [int(.6 *len(rain_clean))])
# Out:
# C:\Users\Lenovo\anaconda3\envs\tensorflow\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
train_set.shape,test_set.shape
# Out:
# ((121, 7), (82, 7))

# %%
train_set, val_set= np.split(train_set, [int(.8 *len(train_set))])

# %%
train_set.shape,test_set.shape,val_set.shape
# Out:
# ((96, 7), (82, 7), (25, 7))

# %%
x_train=train_set.drop(["date","Real Data","SPEI","LST_DAY","LST_Night"],axis=1)
y_train=train_set["Real Data"]

# %%
x_test=test_set.drop(["date","Real Data","SPEI","LST_DAY","LST_Night"],axis=1)
y_test=test_set["Real Data"]

# %%
x_val=val_set.drop(["date","Real Data","SPEI","LST_DAY","LST_Night"],axis=1)
y_val=val_set["Real Data"]

# %%
x_train.shape,y_train.shape
# Out:
# ((96, 2), (96,))

# %%
x_test.shape,y_test.shape
# Out:
# ((82, 2), (82,))

# %%
x_val.shape,y_val.shape
# Out:
# ((25, 2), (25,))

# %% [markdown]
# ### Let me walk You the through the process:
# \\\ there the values from (2001-2019) and for each year it consists of 12 month.
# ### 1.  Sampling Rate:
# ---The interval at which you sample the data.
# ---It should reflect the granularity of the time sequence. If you are dealing with monthly data and want to maintain the sequence at a monthly level, the sampling rate can be 1, indicating that the data is sampled each month.
# ### 2. Sequence Length:
# ---The number of previous time steps to include in each input sequence.
# ---This determines how many previous time steps (months) you will use to predict the next. A reasonable starting point for monthly data might be 12, indicating that you use one year of data to make predictions.
# ### 3. Batch Size:
# ---The number of sequences to process together in each training iteration.
# ---Given that you only have 96 rows, a smaller batch size (like 1 or 2) would allow more frequent updates during training.

# %%
tf.random.set_seed(1234)
sampling_rate = 1
sequence_length =12
#delay = sampling_rate * (sequence_length + 24 - 1)
batch_size = 1
train_dataset=keras.utils.timeseries_dataset_from_array(data=x_train,targets=y_train,sampling_rate=sampling_rate,sequence_length=sequence_length,shuffle=True,batch_size=batch_size)
test_dataset=keras.utils.timeseries_dataset_from_array(data=x_test,targets=y_test,sampling_rate=sampling_rate,sequence_length=sequence_length,shuffle=True,batch_size=batch_size)
val_dataset=keras.utils.timeseries_dataset_from_array(data=x_val,targets=y_val,sampling_rate=sampling_rate,sequence_length=sequence_length,shuffle=True,batch_size=batch_size)

# %%
from keras import layers

# %%
def r2_score(y_true, y_pred):
    ss_res = tf.reduce_sum(tf.square(y_true - y_pred))
    ss_tot = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true)))
    return 1 - ss_res / (ss_tot + tf.keras.backend.epsilon())

# %% [markdown]
# ### RNN model architechture

# %% [raw]
# from keras import regularizers
# inputs=keras.Input(shape=(sequence_length,2))
# x=layers.LSTM(128,recurrent_dropout=0.3,return_sequences=True)(inputs)
#
# for shape in (32,128,128,256):
#     residual=layers.Dense(shape,kernel_regularizer=regularizers.l2(0.002),activation="relu")(x)
#     x=layers.LSTM(shape,recurrent_dropout=0.3,return_sequences=True)(x)
#     x=layers.Dropout(0.1)(x)
#     x =layers.Dense(shape,kernel_regularizer=regularizers.l2(0.002),activation="relu")(x)
#     x=layers.add([x,residual])
#     x=layers.Dropout(0.1)(x)
#     x=layers.LSTM(shape,recurrent_dropout=0.3,return_sequences=True)(x)
#
#
#
# x=layers.GlobalAveragePooling1D()(x)
# output=layers.Dense(1)(x)
#
# model_encoder_new=keras.Model(inputs,output)

# %% [raw]
# from keras import regularizers
#
# def Rnn_model(hp):
#     inputs=keras.Input(shape=(sequence_length,2))
#
#
#     x=layers.LSTM(
#         units=hp.Int("input_lstm1",min_value=32,max_value=512,step=32),
#         recurrent_dropout=hp.Float("recurrent dropout1",min_value=0.1,max_value=0.5,step=0.1),
#         return_sequences=True
#     )(inputs)
#
#     for i in range(4):
#
#
#         residual=layers.Dense(
#             units=hp.Int(f"Dense first {i+1}",min_value=32,max_value=512,step=32),
#             kernel_regularizer=regularizers.l2(hp.Float(f"regulizer first {i+1}",min_value=0.001,max_value=0.005,step=0.001)),
#             activation=hp.Choice(f"activation first {i+1}",["relu","tanh"])
#         )(x)
#
#
#         x=layers.LSTM(
#             units=hp.Int(f"lstm second{i+1}",min_value=32,max_value=512,step=32),
#         recurrent_dropout=hp.Float(f"recurrent dropout second{i+1}",min_value=0.1,max_value=0.5,step=0.1),
#         return_sequences=True
#         )(x)
#
#         if hp.Boolean("dropout"):
#             x=layers.Dropout(0.1)(x)
#
#
#         x =layers.Dense(
#            units=hp.Int(f"Dense first {i+1}",min_value=32,max_value=512,step=32),
#             kernel_regularizer=regularizers.l2(hp.Float(f"regulizer first {i+1}",min_value=0.001,max_value=0.005,step=0.001)),
#             activation=hp.Choice(f"activation first {i+1}",["relu","tanh"])
#         )(x)
#
#
#         x=layers.add([x,residual])
#
#
#         if hp.Boolean("dropout"):
#             x=layers.Dropout(0.1)(x)
#
#
#         x=layers.LSTM(
#             units=hp.Int(f"lstm fourth {i+1}",min_value=32,max_value=512,step=32),
#         recurrent_dropout=hp.Float(f"recurrent dropout fourth {i+1}",min_value=0.1,max_value=0.5,step=0.1),
#         return_sequences=True
#         )(x)
#
#
#
#     x=layers.GlobalAveragePooling1D()(x)
#     output=layers.Dense(1)(x)
#
#     model_encoder_new=keras.Model(inputs,output)
#
#
#     model_encoder_new.compile(optimizer="rmsprop",
#              loss="mse",
#              metrics=[
#                   keras.metrics.RootMeanSquaredError(name="rmse"),  # RMSE
#                   keras.metrics.MeanAbsoluteError(name="mae"),  # MAE
#              ]
#              )
#     return model_encoder_new
#
# Rnn_model(keras_tuner.HyperParameters())

# %% [raw]
# tuner = keras_tuner.RandomSearch(
#     hypermodel=Rnn_model,
#     objective="val_mae",
#     max_trials=3,
#     executions_per_trial=2,
#     overwrite=True,
#     directory="my_dir",
#     project_name="remotesensing",
# )

# %% [raw]
# tuner.search_space_summary()

# %% [raw]
# tuner.search(train_dataset,validation_data=val_dataset,epochs=5)

# %% [raw]
# tuner.results_summary()

# %% [raw]
# best_architechture_rnn=tuner.get_best_models(num_models=1)[0]
# best_architechture_rnn.save("ctg spei+chirps.keras")

# %% [raw]
# hps=tuner.get_best_hyperparameters(num_trials=1)[0]
# print(hps.values)

# %% [raw]
# ### HYPERPARAMETER FOR TWO DATA
# {'input_lstm1': 192, 'recurrent dropout1': 0.1, 'Dense first 1': 160, 'regulizer first 1': 0.005, 'activation first 1': 'relu', 'lstm second1': 192, 'recurrent dropout second1': 0.4, 'dropout': True, 'lstm fourth 1': 96, 'recurrent dropout fourth 1': 0.2, 'Dense first 2': 288, 'regulizer first 2': 0.001, 'activation first 2': 'relu', 'lstm second2': 384, 'recurrent dropout second2': 0.1, 'lstm fourth 2': 416, 'recurrent dropout fourth 2': 0.1, 'Dense first 3': 224, 'regulizer first 3': 0.001, 'activation first 3': 'relu', 'lstm second3': 64, 'recurrent dropout second3': 0.30000000000000004, 'lstm fourth 3': 480, 'recurrent dropout fourth 3': 0.30000000000000004, 'Dense first 4': 416, 'regulizer first 4': 0.002, 'activation first 4': 'relu', 'lstm second4': 192, 'recurrent dropout second4': 0.30000000000000004, 'lstm fourth 4': 96, 'recurrent dropout fourth 4': 0.30000000000000004}

# %%
best_architechture_rnn=keras.models.load_model("ctg spei+chirps.keras")
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# ...

# %%
best_architechture_rnn.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 12, 2)]      0           []
#
#  lstm (LSTM)                    (None, 12, 192)      149760      ['input_1[0][0]']
#
#  lstm_1 (LSTM)                  (None, 12, 192)      295680      ['lstm[0][0]']
#
#  dropout (Dropout)              (None, 12, 192)      0           ['lstm_1[0][0]']
#
#  dense_1 (Dense)                (None, 12, 160)      30880       ['dropout[0][0]']
#
#  dense (Dense)                  (None, 12, 160)      30880       ['lstm[0][0]']
#
#  add (Add)                      (None, 12, 160)      0           ['dense_1[0][0]',
#                                                                   'dense[0][0]']
#
#  dropout_1 (Dropout)            (None, 12, 160)      0           ['add[0][0]']
#
# ...

# %% [raw]
# callbacks=keras.callbacks.ModelCheckpoint("ctg spei+chirps final.keras",save_best_only=True,monitor="val_loss")
# best_architechture_rnn.compile(optimizer="rmsprop",
#              loss="mse",
#              metrics=[
#                   keras.metrics.RootMeanSquaredError(name="rmse"),  # RMSE
#                   keras.metrics.MeanAbsoluteError(name="mae"),  # MAE
#              ]
#              )
# history3=best_architechture_rnn.fit(train_dataset,validation_data=val_dataset,epochs=20,callbacks=[callbacks])

# %%
model_rnn_new= keras.models.load_model("ctg spei+chirps final.keras",custom_objects={'r2_score': r2_score})
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# ...

# %%
results=model_rnn_new.evaluate(test_dataset)
# Out:
# 71/71 [==============================] - 12s 132ms/step - loss: 0.1963 - rmse: 0.4370 - mae: 0.3085

# %%
from tabulate import tabulate
table = [
    ["Algorithm",  "RNN"],
    ["RMSE", results[1]],
    ["MAE", results[2]]
]

# Display the table
print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# ╒═════════════╤══════════╕
# │ Algorithm   │      RNN │
# ╞═════════════╪══════════╡
# │ RMSE        │ 0.436961 │
# ├─────────────┼──────────┤
# │ MAE         │ 0.30853  │
# ╘═════════════╧══════════╛

# %%
keras.utils.plot_model(model_rnn_new, show_shapes=True,dpi=65)

# %%
keras.utils.plot_model(best_architechture_rnn, show_shapes=True,dpi=65)
